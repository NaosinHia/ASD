# %% [markdown]
# # Installation

# %%
# !pip install pandas
# !pip install opencv-python==4.6.0.66
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\admin\.conda\envs\thesis\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)
# Requirement already satisfied: opencv-python==4.6.0.66 in c:\users\admin\.conda\envs\thesis\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from opencv-python==4.6.0.66) (1.26.1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)
# Requirement already satisfied: seaborn in c:\users\admin\.conda\envs\thesis\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)
# Requirement already satisfied: scikit-learn in c:\users\admin\.conda\envs\thesis\lib\site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\.conda\envs\thesis\lib\site-packages (from scikit-learn) (3.2.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\.conda\envs\thesis\lib\site-packages)

# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd 


import os
for dirname, _, filenames in os.walk('C:/Users/Admin/Downloads/Thesis Code/AutismDataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import random
import os

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models, Sequential
from tensorflow.keras import optimizers

from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.applications.vgg16 import VGG16

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
# Out:
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0001.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0002.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0003.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0004.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0005.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0006.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0007.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0008.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0009.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0010.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0011.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0012.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0013.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0014.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0015.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0016.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0017.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0018.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0019.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0020.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0021.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0022.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0023.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0024.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0025.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0026.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0027.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0028.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0029.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0030.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0031.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0032.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0033.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0034.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0035.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0036.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0037.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0038.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0039.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0040.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0041.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0042.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0043.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0044.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0045.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0046.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0047.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0048.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0049.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0050.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0051.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0052.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0053.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0054.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0055.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0056.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0057.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0058.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0059.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0060.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0061.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0062.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0063.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0064.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0065.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0066.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0067.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0068.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0069.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0070.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0071.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0072.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0073.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0074.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0075.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0076.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0077.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0078.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0079.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0080.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0081.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0082.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0083.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0084.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0085.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0086.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0087.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0088.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0089.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0090.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0091.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0092.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0093.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0094.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0095.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0096.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0097.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0098.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0099.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0100.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0101.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0102.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0103.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0104.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0105.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0106.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0107.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0108.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0109.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0110.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0111.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0112.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0113.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0114.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0115.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0116.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0117.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0118.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0119.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0120.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0121.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0122.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0123.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0124.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0125.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0126.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0127.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0128.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0129.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0130.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0131.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0132.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0133.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0134.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0135.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0136.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0137.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0138.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0139.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0140.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0141.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0142.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0143.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0144.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0145.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0146.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0147.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0148.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0149.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0150.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0151.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0152.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0153.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0154.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0155.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0156.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0157.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0158.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0159.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0160.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0161.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0162.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0163.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0164.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0165.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0166.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0167.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0168.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0169.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0170.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0171.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0172.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0173.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0174.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0175.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0176.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0177.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0178.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0179.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0180.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0181.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0182.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0183.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0184.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0185.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0186.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0187.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0188.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0189.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0190.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0191.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0192.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0193.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0194.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0195.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0196.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0197.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0198.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0199.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0200.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0201.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0202.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0203.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0204.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0205.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0206.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0207.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0208.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0209.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0210.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0211.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0212.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0213.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0214.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0215.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0216.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0217.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0218.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0219.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0220.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0221.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0222.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0223.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0224.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0225.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0226.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0227.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0228.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0229.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0230.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0231.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0232.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0233.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0234.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0235.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0236.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0237.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0238.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0239.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0240.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0241.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0242.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0243.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0244.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0245.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0246.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0247.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0248.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0249.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0250.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0251.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0252.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0253.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0254.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0255.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0256.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0257.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0258.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0259.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0260.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0261.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0262.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0263.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0264.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0265.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0266.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0267.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0268.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0269.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0270.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0271.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0272.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0273.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0274.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0275.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0276.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0277.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0278.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0279.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0280.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0281.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0282.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0283.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0284.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0285.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0286.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0287.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0288.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0289.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0290.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0291.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0292.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0293.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0294.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0295.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0296.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0297.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0298.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0299.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0300.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0301.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0302.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0303.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0304.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0305.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0306.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0307.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0308.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0309.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0310.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0311.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0312.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0313.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0314.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0315.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0316.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0317.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0318.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0319.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0320.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0321.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0322.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0323.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0324.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0325.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0326.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0327.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0328.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0329.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0330.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0331.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0332.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0333.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0334.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0335.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0336.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0337.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0338.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0339.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0340.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0341.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0342.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0343.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0344.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0345.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0346.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0347.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0348.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0349.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0350.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0351.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0352.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0353.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0354.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0355.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0356.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0357.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0358.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0359.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0360.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0361.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0362.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0363.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0364.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0365.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0366.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0367.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0368.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0369.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0370.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0371.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0372.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0373.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0374.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0375.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0376.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0377.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0378.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0379.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0380.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0381.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0382.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0383.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0384.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0385.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0386.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0387.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0388.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0389.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0390.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0391.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0392.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0393.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0394.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0395.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0396.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0397.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0398.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0399.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0400.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0401.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0402.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0403.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0404.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0405.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0406.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0407.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0408.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0409.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0410.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0411.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0412.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0413.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0414.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0415.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0416.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0417.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0418.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0419.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0420.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0421.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0422.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0423.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0424.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0425.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0426.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0427.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0428.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0429.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0430.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0431.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0432.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0433.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0434.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0435.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0436.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0437.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0438.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0439.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0440.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0441.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0442.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0443.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0444.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0445.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0446.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0447.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0448.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0449.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0450.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0451.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0452.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0453.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0454.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0455.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0456.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0457.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0458.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0459.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0460.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0461.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0462.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0463.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0464.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0465.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0466.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0467.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0468.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0469.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0470.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0471.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0472.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0473.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0474.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0475.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0476.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0477.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0478.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0479.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0480.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0481.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0482.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0483.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0484.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0485.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0486.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0487.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0488.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0489.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0490.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0491.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0492.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0493.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0494.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0495.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0496.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0497.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0498.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0499.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0500.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0501.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0502.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0503.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0504.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0505.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0506.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0507.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0508.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0509.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0510.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0511.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0512.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0513.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0514.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0515.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0516.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0517.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0518.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0519.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0520.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0521.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0522.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0523.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0524.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0525.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0526.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0527.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0528.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0529.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0530.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0531.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0532.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0533.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0534.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0535.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0536.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0537.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0538.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0539.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0540.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0541.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0542.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0543.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0544.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0545.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0546.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0547.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0548.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0549.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0550.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0551.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0552.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0553.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0554.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0555.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0556.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0557.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0558.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0559.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0560.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0561.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0562.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0563.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0564.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0565.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0566.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0567.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0568.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0569.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0570.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0571.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0572.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0573.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0574.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0575.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0576.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0577.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0578.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0579.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0580.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0581.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0582.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0583.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0584.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\consolidated\Autistic\0585.jpg
# ...
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.913.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.914.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.915.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.916.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.917.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.918.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.919.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.92.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.920.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.921.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.922.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.923.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.924.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.925.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.926.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.927.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.928.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.929.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.93.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.930.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.931.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.932.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.933.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.934.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.935.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.936.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.937.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.938.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.939.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.94.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.940.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.941.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.942.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.943.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.944.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.945.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.946.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.947.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.948.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.949.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.95.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.950.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.951.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.952.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.953.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.954.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.955.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.956.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.957.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.958.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.959.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.96.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.960.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.961.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.962.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.963.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.964.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.965.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.966.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.967.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.968.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.969.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.97.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.970.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.971.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.972.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.973.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.974.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.975.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.976.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.977.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.978.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.979.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.98.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.980.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.981.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.982.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.983.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.984.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.985.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.986.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.987.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.988.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.989.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.99.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.990.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.991.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.992.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.993.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.994.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.995.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.996.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.997.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.998.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train\Non_Autistic.999.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train2\Autistic-1.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train2\Autistic-2.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train2\Non-Autistic-1.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\train2\Non-Autistic-2.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\01.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\02.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\03.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\04.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\05.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\06.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\07.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\08.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\09.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\10.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\11.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\12.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\13.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\14.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\15.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\16.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\17.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\18.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\19.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\20.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\21.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\22.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\23.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\24.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\25.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\26.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\27.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\28.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\29.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\30.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\31.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\32.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\33.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\34.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\35.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\36.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\37.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\38.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\39.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\40.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\41.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\42.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\43.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\44.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\45.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\46.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\47.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\48.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\49.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Autistic\50.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\01.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\02.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\03.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\04.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\05.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\06.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\07.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\08.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\09.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\10.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\11.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\12.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\13.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\14.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\15.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\16.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\17.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\18.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\19.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\20.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\21.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\22.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\23.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\24.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\25.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\26.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\27.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\28.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\29.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\30.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\31.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\32.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\33.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\34.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\35.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\36.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\37.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\38.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\39.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\40.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\41.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\42.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\43.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\44.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\45.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\46.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\47.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\48.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\49.jpg
# C:/Users/Admin/Downloads/Thesis Code/AutismDataset\valid\Non_Autistic\50.jpg
# WARNING:tensorflow:From C:\Users\Admin\.conda\envs\thesis\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 24
#      21 from tensorflow.keras import models, Sequential
#      22 from tensorflow.keras import optimizers
# ---> 24 from keras.layers.core import Dense, Dropout, Flatten
#      25 from keras.layers.convolutional import Conv2D, MaxPooling2D, SeparableConv2D
#      26 from tensorflow.keras.layers import BatchNormalization
#
# ModuleNotFoundError: No module named 'keras.layers.core'

# %% [markdown]
# # Train & Test Directories

# %%
train_data = "C:/Users/Admin/Downloads/Thesis Code/AutismDataset/train"
test_data = "C:/Users/Admin/Downloads/Thesis Code/AutismDataset/test"

# %% [markdown]
# # Splitting Autistic & Non-Autistic

# %%
train_non_autistic = []
train_autistic = []

for i in os.listdir(train_data):
    if 'Non_Autistic' in i:
        train_non_autistic.append(os.path.join(train_data, i))
    else:
        train_autistic.append(os.path.join(train_data, i))

test_non_autistic = []
test_autistic = []

for i in os.listdir(test_data):
    if 'Non_Autistic' in i:
        test_non_autistic.append(os.path.join(test_data, i))
    else:
        test_autistic.append(os.path.join(test_data, i))

# %%
train_imgs = train_autistic + train_non_autistic
random.shuffle(train_imgs)

# %%
test_imgs = test_autistic + test_non_autistic
random.shuffle(test_imgs)

# %%
import matplotlib.image as mpimg
for ima in train_imgs[0:1]:
    img=mpimg.imread(ima)
    imgplot = plt.imshow(img)
    plt.show()

# %%
import matplotlib.image as mpimg
for ima in test_imgs[0:1]:
    img=mpimg.imread(ima)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# # Resizing The Images

# %%
def read_and_process_image(list_of_images):
    X = []
    y = []
    
    for image_path in list_of_images:
        # Read and resize the image
        img = cv2.resize(cv2.imread(image_path, cv2.IMREAD_COLOR), (224, 224), interpolation=cv2.INTER_CUBIC)
        
        if 'Non_Autistic' in image_path:
            y.append(0)
        else:
            y.append(1)
            
    return X, y

X_train, y_train = read_and_process_image(train_imgs)
X_test, y_test = read_and_process_image(test_imgs)

# %% [markdown]
# # Validation Data

# %%
val_autistic = "/Users/Admin/Downloads/Thesis Code/AutismDataset/valid/Autistic"
val_non_autistic = "/Users/Admin/Downloads/Thesis Code/AutismDataset/valid/Non_Autistic"
val_autistic_imgs = ["/Users/Admin/Downloads/Thesis Code/AutismDataset/valid/Autistic/{}".format(i) for i in os.listdir(val_autistic)]
val_non_autistic_imgs = ["/Users/Admin/Downloads/Thesis Code/AutismDataset/valid/Non_Autistic/{}".format(i) for i in os.listdir(val_non_autistic)]
val_imgs = val_autistic_imgs + val_non_autistic_imgs
random.shuffle(val_imgs)

# %%
X_val, y_val = read_and_process_image(val_imgs)

# %%
import matplotlib.image as mpimg
for ima in val_imgs[0:1]:
    img=mpimg.imread(ima)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# # Shape Of Data

# %%
# print("Shape of Train images:", X_train.shape)
# print("Shape of Train labels:", y_train.shape)
# print("Shape of validation images:", X_val.shape)
# print("Shape of validation labels:", y_val.shape)

# %% [markdown]
# # Preprocessing

# %%
def preprocess_image(train_data, target_size=(224, 224)):
    # Read the image
    image = cv2.imread(train_data, cv2.IMREAD_COLOR)
    
    # Resize the image
    if target_size:
        image = cv2.resize(image, target_size, interpolation=cv2.INTER_CUBIC)
    
    # Normalize pixel values
    image = image / 255.0
    
    return image

X_train = [preprocess_image(train_data) for train_data in train_imgs]
X_test = [preprocess_image(test_data) for test_data in test_imgs]
X_val = [preprocess_image(val_data) for val_data in val_imgs]

# %% [markdown]
# # Converting Train & Val Data To np Array

# %%
import numpy as np

X_train = np.array(X_train)
X_test = np.array(X_test)
X_val = np.array(X_val)


# Assuming y_train, y_val, and y_test are 1D arrays
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# # Expand dimensions to create 4D arrays
# y_train_expanded = np.expand_dims(y_train, axis=0)
# y_val_expanded = np.expand_dims(y_val, axis=0)
# y_test_expanded = np.expand_dims(y_test, axis=0)

# %% [markdown]
# # Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Assuming X_train, X_val, and X_test are 4D arrays
# If they are 3D, you may need to add an extra dimension
# X_train = np.expand_dims(X_train, axis=0)
# X_val = np.expand_dims(X_val, axis=0)
# X_test = np.expand_dims(X_test, axis=0)

# Assuming y_train, y_val, and y_test are properly formatted labels

# Generating Larger DataSet - Data Augmentation
train_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=4,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Creating ImageDataGenerator generators
batch_size = 32
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)
test_generator = test_datagen.flow(X_test, y_test, batch_size=batch_size)

# %%
#Model

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# Load MobileNet base model
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)  # Add your desired number of units
predictions = Dense(1, activation='sigmoid')(x)  # 'num_classes' should be the number of classes in your dataset

# Create the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# %%
# Define number of epochs
epochs = 10  # You can adjust this number

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=len(X_train) // batch_size,
    epochs=epochs,
    validation_data=val_generator,
    validation_steps=len(X_val) // batch_size
)

# %%
# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_generator, steps=len(X_test) // batch_size)
print("Test Accuracy:", test_accuracy)

# %% [markdown]
# #Shap

# %%
SIZE = 224  #Resize images
import glob
import os
import numpy as np
import cv2
#Capture training data and labels into respective lists
# train_images = []
# train_labels = [] 

# for directory_path in glob.glob("C:/Users/WIN10/Desktop/Skin_Diseases_Test -6/data/test/*"):
#     label = directory_path.split("\\")[-1]
#     print(label)
#     for img_path in glob.glob(os.path.join(directory_path, "*")):
#         print(img_path)

img_path= ("C:/Users/Admin/Downloads/Thesis Code/AutismDataset/train/Autistic-1.jpg")
img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
img = cv2.resize(img, (SIZE, SIZE))
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# #Convert lists to arrays        
# train_images = np.array(train_images)
# train_labels = np.array(train_labels)
# X = train_images


import json

# from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()
import shap
import cv2
import random


def f(X):
    tmp = X.copy()
    return model(tmp)		#ekhane model er name



class_names = ['Non-Autistic', 'Autistic']

# define a masker that is used to mask out partitions of the input image, this one uses a blurred background
masker = shap.maskers.Image("inpaint_telea", img.shape)

# By default the Partition explainer is used for all  partition explainer
explainer = shap.Explainer(f, masker, output_names=class_names)
shap_values = explainer(
img, max_evals=500, outputs=shap.Explanation.argsort.flip[:1]
)
shap.image_plot(shap_values)

# sup=[312, 288, 309, 261, 352, 343, 325]
# sum=0
# for j in sup:    
#     i = random.randint(sum,sum+j-1)
#     sum=sum+j
#     print(i, train_labels[i])
#     shap_values = explainer(
#     X[i:i+1], max_evals=500, batch_size=8, outputs=shap.Explanation.argsort.flip[:1]
#     )
#     shap.image_plot(shap_values)
